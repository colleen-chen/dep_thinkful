# %%
import numpy as np
import pandas as pd
import scipy
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.preprocessing import normalize
from sklearn.decomposition import PCA
from sklearn.cluster import MiniBatchKMeans
# %matplotlib inline

# %%
df = pd.read_csv("https://raw.githubusercontent.com/Thinkful-Ed/data-201-resources/master/cleveland.csv", header=None, error_bad_lines=False)

# Define the features and the outcome.
X = df.iloc[:, :13]
y = df.iloc[:, 13]

# Replace missing values (marked by ?) with a 0.
X = X.replace(to_replace='?', value=0)

# Binarize y so that 1 means heart disease diagnosis and 0 means no diagnosis.
y = np.where(y > 0, 0, 1)

# %% [markdown]
# ## Here is the case k = 3
# >

# %%
# set k_const
k_const = 3
# Normalize the data.
X_norm = normalize(X)

# Reduce it to two components.
X_pca = PCA(k_const).fit_transform(X_norm)

# Calculate predicted values.
y_pred = KMeans(n_clusters=k_const, random_state=42).fit_predict(X_pca)

# Plot the solution.
fig = plt.figure()
fig.add_subplot(221)
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y_pred)
fig.add_subplot(222)
plt.scatter(X_pca[:, 0], X_pca[:, 2], c=y_pred)
fig.add_subplot(223)
plt.scatter(X_pca[:, 1], X_pca[:, 2], c=y_pred)
plt.show()

# Check the solution against the data.
print('Comparing k-means clusters against the data:')
print(pd.crosstab(y_pred, y))
# Out:
# Comparing k-means clusters against the data:
# col_0   0   1
# row_0
# 0      49  33
# 1      26  61
# 2      64  70

# %% [markdown]
# ## here is the case k=4
# >

# %%
# set k_const
k_const = 4
# Normalize the data.
X_norm = normalize(X)

# Reduce it to two components.
X_pca = PCA(k_const).fit_transform(X_norm)

# Calculate predicted values.
y_pred = KMeans(n_clusters=k_const, random_state=42).fit_predict(X_pca)

# Plot the solution.
fig = plt.figure()
fig.add_subplot(331)
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y_pred)
fig.add_subplot(332)
plt.scatter(X_pca[:, 0], X_pca[:, 2], c=y_pred)
fig.add_subplot(333)
plt.scatter(X_pca[:, 0], X_pca[:, 3], c=y_pred)
fig.add_subplot(334)
plt.scatter(X_pca[:, 1], X_pca[:, 2], c=y_pred)
fig.add_subplot(335)
plt.scatter(X_pca[:, 1], X_pca[:, 3], c=y_pred)
fig.add_subplot(337)
plt.scatter(X_pca[:, 2], X_pca[:, 3], c=y_pred)
plt.show()

# Check the solution against the data.
print('Comparing k-means clusters against the data:')
print(pd.crosstab(y_pred, y))
# Out:
# Comparing k-means clusters against the data:
# col_0   0   1
# row_0
# 0      43  26
# 1      17  51
# 2      42  21
# 3      37  66

# %%
# set k_const
k_const = 5
# Normalize the data.
X_norm = normalize(X)

# Reduce it to two components.
X_pca = PCA(k_const).fit_transform(X_norm)

# Calculate predicted values.
y_pred = KMeans(n_clusters=k_const, random_state=42).fit_predict(X_pca)

# Plot the solution.
fig = plt.figure()
fig.add_subplot(4,4,1)
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y_pred)
fig.add_subplot(4,4,2)
plt.scatter(X_pca[:, 0], X_pca[:, 2], c=y_pred)
fig.add_subplot(4,4,3)
plt.scatter(X_pca[:, 0], X_pca[:, 3], c=y_pred)
fig.add_subplot(4,4,4)
plt.scatter(X_pca[:, 0], X_pca[:, 4], c=y_pred)
fig.add_subplot(4,4,5)
plt.scatter(X_pca[:, 1], X_pca[:, 2], c=y_pred)
fig.add_subplot(4,4,6)
plt.scatter(X_pca[:, 1], X_pca[:, 3], c=y_pred)
fig.add_subplot(4,4,7)
plt.scatter(X_pca[:, 1], X_pca[:, 4], c=y_pred)
fig.add_subplot(4,4,9)
plt.scatter(X_pca[:, 2], X_pca[:, 3], c=y_pred)
fig.add_subplot(4,4,10)
plt.scatter(X_pca[:, 2], X_pca[:, 4], c=y_pred)
fig.add_subplot(4,4,13)
plt.scatter(X_pca[:, 3], X_pca[:, 4], c=y_pred)
plt.show()

# Check the solution against the data.
print('Comparing k-means clusters against the data:')
print(pd.crosstab(y_pred, y))
# Out:
# Comparing k-means clusters against the data:
# col_0   0   1
# row_0
# 0      14  57
# 1      40  28
# 2      34  46
# 3      15  22
# 4      36  11

# %%
# set k_const
k_const = 6
# Normalize the data.
X_norm = normalize(X)

# Reduce it to two components.
X_pca = PCA(k_const).fit_transform(X_norm)

# Calculate predicted values.
y_pred = KMeans(n_clusters=k_const, random_state=42).fit_predict(X_pca)

# Plot the solution.
# Plot the solution.
fig = plt.figure()
fig.add_subplot(5,5,1)
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y_pred)
fig.add_subplot(5,5,2)
plt.scatter(X_pca[:, 0], X_pca[:, 2], c=y_pred)
fig.add_subplot(5,5,3)
plt.scatter(X_pca[:, 0], X_pca[:, 3], c=y_pred)
fig.add_subplot(5,5,4)
plt.scatter(X_pca[:, 0], X_pca[:, 4], c=y_pred)
fig.add_subplot(5,5,5)
plt.scatter(X_pca[:, 0], X_pca[:, 5], c=y_pred)
fig.add_subplot(5,5,6)
plt.scatter(X_pca[:, 1], X_pca[:, 2], c=y_pred)
fig.add_subplot(5,5,7)
plt.scatter(X_pca[:, 1], X_pca[:, 3], c=y_pred)
fig.add_subplot(5,5,8)
plt.scatter(X_pca[:, 1], X_pca[:, 4], c=y_pred)
fig.add_subplot(5,5,9)
plt.scatter(X_pca[:, 1], X_pca[:, 5], c=y_pred)
fig.add_subplot(5,5,11)
plt.scatter(X_pca[:, 2], X_pca[:, 3], c=y_pred)
fig.add_subplot(5,5,12)
plt.scatter(X_pca[:, 2], X_pca[:, 4], c=y_pred)
fig.add_subplot(5,5,13)
plt.scatter(X_pca[:, 2], X_pca[:, 5], c=y_pred)
fig.add_subplot(5,5,16)
plt.scatter(X_pca[:, 3], X_pca[:, 4], c=y_pred)
fig.add_subplot(5,5,17)
plt.scatter(X_pca[:, 3], X_pca[:, 5], c=y_pred)
fig.add_subplot(5,5,21)
plt.scatter(X_pca[:, 4], X_pca[:, 5], c=y_pred)
plt.show()

# Check the solution against the data.
print('Comparing k-means clusters against the data:')
print(pd.crosstab(y_pred, y))
# Out:
# Comparing k-means clusters against the data:
# col_0   0   1
# row_0
# 0      21  15
# 1      35  11
# 2      13  51
# 3      31  20
# 4      34  45
# 5       5  22

# %% [markdown]
# With k values from 2 to 6, no solution is most compelling.
